# %% [markdown]
# # PrimerNotebook

# %% [markdown]
# ### Este es mi primer notebook y vamos a hacer lo siguiente

# %% [markdown]
# Vamos a hacer una lista **enumerada**
# 1. primero
# 2. segundo
# 3. tercero

# %% [markdown]
# Lista por **puntos**
# * Uno
# * Dos
# * Tres

# %% [markdown]
# Mi primer codigo

# %% [markdown]
# mi_primera_frase = "hola mundo"

# %%
print(mi_primera_frase)
# Out:
# hola mundo

# %%
numeros = (2,4,6,8,10)

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 6.0

# %% [markdown]
# ## Un bonito animal

# %% [markdown]
# ![500px-British_shorthair_Irina_AEA.jpg](attachment:79082a17-6ded-48d0-afe7-4ec5fbdc7a19.jpg)
